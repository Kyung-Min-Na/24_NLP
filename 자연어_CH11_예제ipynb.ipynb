# %% [markdown]
# <a href="https://colab.research.google.com/github/Kyung-Min-Na/24_NLP/blob/main/%EC%9E%90%EC%97%B0%EC%96%B4_CH11_%EC%98%88%EC%A0%9Cipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library install

# %%
pip install BeautifulSoup4

# %%
pip install finance-datareader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 1.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Data download & drawing

# %%
import FinanceDataReader as fdr
import numpy as np
import matplotlib.pyplot as plt

# %%
# 삼성전자 코드=005930, 2020년 데이터부터 다운로드한다.
samsung = fdr.DataReader('005930', '2020')

# 시작가만 얻는다.
seq_data = (samsung[['Open']]).to_numpy()

# %%
# 선형 그래프로 그린다.
plt.plot(seq_data, color='blue')
plt.title("Samsung Electronics Stock Price")
plt.xlabel("days")
plt.xlabel("")
plt.show()
